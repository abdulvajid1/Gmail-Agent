# %%
from langchain_core.messages import convert_to_openai_messages
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
from pprint import pprint
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

from src.utils import setup_client

# %%
msg = [
    SystemMessage('You are a Helpfull AI Assistent'),
    HumanMessage('who is the prime minister of india')
]

pprint(convert_to_openai_messages(msg))
# Out:
# [{'content': 'You are a Helpfull AI Assistent', 'role': 'system'},
#  {'content': 'who is the prime minister of india', 'role': 'user'}]

# %%
client = setup_client()

# %%
output = client.chat.completions.create(
    messages=convert_to_openai_messages(msg),
    model='llama3.1'
)

# %%
from src.model import CustomLLM
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from src.model import CustomLLM
#
# File ~/AI/PROJECTS/Gmail-Agent/src/model.py:2
#       1 from langchain_core.language_models import BaseChatModel
# ----> 2 from utils import setup_openai_client
#       3 from langchain_core.messages import convert_to_openai_messages
#       4 from langchain_core.messages import AIMessage, SystemMessage
#
# ModuleNotFoundError: No module named 'utils'

# %%
print(output\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\)
# Out:
# The Prime Minister of India as of my last update in 2023 is Narendra Modi. He has been the leader of the National Democratic Alliance (NDA) since May 2014 and took office on May 26, 2014, becoming the first Prime Minister from the state of Gujarat to serve two consecutive terms.
#
# However, please note that this information may change over time due to elections or other governance changes. For the most up-to-date information, I recommend checking official government sources or reputable news outlets.
